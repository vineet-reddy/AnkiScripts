# %% [markdown]
# This script uses the Anthropic API to generate example sentences for vocabulary words in an Anki deck, enhancing GRE study by adding example sentences to vocab flashcards.
#
# ### Overview:
# 1. **Setup**: Imports necessary libraries and initializes the Claude API client with the user’s API key, AnkiConnect URL, and Anki deck name.
# 2. **AnkiConnect Functions**:
#    - `get_notes()`: Fetches note IDs in the specified deck.
#    - `get_note_info()`: Retrieves details of each note.
#    - `update_note_fields()`: Updates a note’s field with a generated sentence.
# 3. **Formatting**: `clean_and_bold_sentence()` formats the sentence, bolding the vocabulary word.
# 4. **Main Process**:
#    - For each note with an empty "BackAudio" field, the script sends a request to Claude Sonnet to generate an example sentence for the word in "FrontText".
#    - The formatted sentence is then added to the note’s "BackAudio" field.
#
# This process automates the creation of example sentences, adding contextual learning to Anki GRE vocab cards.

# %%
import requests
import json
import re
import anthropic

# Set your Claude API key here
claude_api_key = os.getenv("CLAUDE_API_KEY")
# claude_api_key = "insert_key_here"  # Replace with API key.
# TODO: It's not proper to include an API key in the script directly.
# TODO: Move the key to a virtual environment variable and retrieve it from there.

# AnkiConnect endpoint
ANKI_CONNECT_URL = 'insert_ankiconnect_url_here' # Add default AnkiConnect URL (see documentation - https://github.com/amikey/anki-connect)

# Replace with the name of your deck
deck_name = "GRE Vocab"

# Initialize Claude client
client = anthropic.Anthropic(api_key=claude_api_key)

def get_notes(deck_name):
    payload = {
        "action": "findNotes",
        "version": 6,
        "params": {
            "query": f'deck:"{deck_name}"'
        }
    }
    response = requests.post(ANKI_CONNECT_URL, json=payload).json()
    if response.get('error'):
        print(f"AnkiConnect Error: {response['error']}")
        return []
    return response['result']

def get_note_info(note_ids):
    payload = {
        "action": "notesInfo",
        "version": 6,
        "params": {
            "notes": note_ids
        }
    }
    response = requests.post(ANKI_CONNECT_URL, json=payload).json()
    if response.get('error'):
        print(f"AnkiConnect Error: {response['error']}")
        return []
    return response['result']

def update_note_fields(note_id, fields):
    payload = {
        "action": "updateNoteFields",
        "version": 6,
        "params": {
            "note": {
                "id": note_id,
                "fields": fields
            }
        }
    }
    response = requests.post(ANKI_CONNECT_URL, json=payload).json()
    if response.get('error'):
        print(f"AnkiConnect Error: {response['error']}")
    return response

def clean_and_bold_sentence(sentence, word):
    # Remove any "Here's an example..." or similar prefix
    cleaned_sentence = re.sub(r'^.*?:\s*', '', sentence)
    cleaned_sentence = re.sub(r'^Here\'s\s+', '', cleaned_sentence)
    cleaned_sentence = re.sub(r'^Let me create\s+', '', cleaned_sentence)
    
    # Remove quotes if they wrap the entire sentence
    cleaned_sentence = re.sub(r'^\s*["\'](.+)["\']$', r'\1', cleaned_sentence.strip())
    
    # Ensure the word is bolded
    escaped_word = re.escape(word)
    pattern = r"\b" + escaped_word + r"\b"
    
    # Remove any existing bold tags around the word
    cleaned_sentence = re.sub(r'</?b>', '', cleaned_sentence)
    
    # Add new bold tags
    bolded_sentence = re.sub(pattern, f"<b>{word}</b>", cleaned_sentence, flags=re.IGNORECASE)
    
    return bolded_sentence.strip()

# Main script
note_ids = get_notes(deck_name)
if not note_ids:
    print("No notes found in the deck.")
    exit()

notes_info = get_note_info(note_ids)

for note in notes_info:
    fields = note['fields']
    front_text = fields['FrontText']['value']
    back_audio = fields['BackAudio']['value']

    # Check if BackAudio is empty
    if not back_audio.strip():
        word = front_text.strip()
        
        # Create the properly formatted prompt for Claude
        messages = [
            {
                "role": "user",
                "content": f"Create a simple example sentence using the word '{word}'. Provide only the sentence, without any introduction or quotes."
            }
        ]
        
        try:
            response = client.messages.create(
                model="claude-3-sonnet-20240229",
                max_tokens=100,
                messages=messages
            )
            
            example_sentence = response.content[0].text.strip()
            
            # Clean and bold the sentence
            final_sentence = clean_and_bold_sentence(example_sentence, word)

            # Update the BackAudio field in the note
            update_note_fields(note['noteId'], {"BackAudio": final_sentence})
            print(f"Updated note with FrontText '{front_text}' with new example sentence.")
            
        except Exception as e:
            print(f"Error processing word '{word}': {str(e)}")
# Out:
# Updated note with FrontText 'amorphous' with new example sentence.
# Updated note with FrontText 'cerebral' with new example sentence.
# Updated note with FrontText 'advocate' with new example sentence.
# Updated note with FrontText 'aggrandize' with new example sentence.
# Updated note with FrontText 'ambivalent' with new example sentence.
# Updated note with FrontText 'ameliorate' with new example sentence.
# Updated note with FrontText 'amenable' with new example sentence.
# Updated note with FrontText 'anachronistic' with new example sentence.
# Updated note with FrontText 'audacious' with new example sentence.
# Updated note with FrontText 'benign' with new example sentence.
# Updated note with FrontText 'convoluted' with new example sentence.
# Updated note with FrontText 'covet' with new example sentence.
# Updated note with FrontText 'abate' with new example sentence.
# Updated note with FrontText 'anomalous' with new example sentence.
# Updated note with FrontText 'arduous' with new example sentence.
# Updated note with FrontText 'ascetic' with new example sentence.
# Updated note with FrontText 'betray' with new example sentence.
# Updated note with FrontText 'burgeon' with new example sentence.
# Updated note with FrontText 'censure' with new example sentence.
# Updated note with FrontText 'coalesce' with new example sentence.
# Updated note with FrontText 'compelling' with new example sentence.
# Updated note with FrontText 'copious' with new example sentence.
# Updated note with FrontText 'abstain' with new example sentence.
# Updated note with FrontText 'cherish' with new example sentence.
# Updated note with FrontText 'conventional' with new example sentence.
# Updated note with FrontText 'aesthetic' with new example sentence.
# Updated note with FrontText 'alleviate' with new example sentence.
# Updated note with FrontText 'analogous' with new example sentence.
# Updated note with FrontText 'bolster' with new example sentence.
# Updated note with FrontText 'connoisseur' with new example sentence.
# Updated note with FrontText 'appease' with new example sentence.
# Updated note with FrontText 'arbitrary' with new example sentence.
# Updated note with FrontText 'archaic' with new example sentence.
# Updated note with FrontText 'accentuate' with new example sentence.
# Updated note with FrontText 'cordial' with new example sentence.
# Updated note with FrontText 'antithesis' with new example sentence.
# Updated note with FrontText 'ascribe' with new example sentence.
# Updated note with FrontText 'abhor' with new example sentence.
# Updated note with FrontText 'boisterous' with new example sentence.
# Updated note with FrontText 'chivalrous' with new example sentence.
# Updated note with FrontText 'complacent' with new example sentence.
# Updated note with FrontText 'belligerent' with new example sentence.
# Updated note with FrontText 'beneficent' with new example sentence.
# Updated note with FrontText 'affinity' with new example sentence.
# Updated note with FrontText 'altruistic' with new example sentence.
# Updated note with FrontText 'compromise' with new example sentence.
# Updated note with FrontText 'covert' with new example sentence.
# Updated note with FrontText 'credible' with new example sentence.
# Updated note with FrontText 'acquiesce' with new example sentence.
# Updated note with FrontText 'amend' with new example sentence.
# Updated note with FrontText 'collaborate' with new example sentence.
# Updated note with FrontText 'competent' with new example sentence.
# Updated note with FrontText 'correlate' with new example sentence.
# Updated note with FrontText 'alienate' with new example sentence.
# Updated note with FrontText 'apathy' with new example sentence.
# Updated note with FrontText 'apt' with new example sentence.
# Updated note with FrontText 'cloak' with new example sentence.
# Updated note with FrontText 'consensus' with new example sentence.
# Updated note with FrontText 'banish' with new example sentence.
# Updated note with FrontText 'comply' with new example sentence.
# Updated note with FrontText 'curtail' with new example sentence.
# Updated note with FrontText 'acclaim' with new example sentence.
# Updated note with FrontText 'assertive' with new example sentence.
# Updated note with FrontText 'bogus' with new example sentence.
# Updated note with FrontText 'complementary' with new example sentence.
# Updated note with FrontText 'contentious' with new example sentence.
# Updated note with FrontText 'accessible' with new example sentence.
# Updated note with FrontText 'amalgamate' with new example sentence.
# Updated note with FrontText 'attenuate' with new example sentence.
# Updated note with FrontText 'augment' with new example sentence.
# Updated note with FrontText 'contempt' with new example sentence.
# Updated note with FrontText 'base' with new example sentence.
# Updated note with FrontText 'coercion' with new example sentence.
# Updated note with FrontText 'coin' with new example sentence.
# Updated note with FrontText 'cunning' with new example sentence.
# Updated note with FrontText 'confound' with new example sentence.
# Updated note with FrontText 'amicable' with new example sentence.
# Updated note with FrontText 'animosity' with new example sentence.
# Updated note with FrontText 'barrage' with new example sentence.
# Updated note with FrontText 'cathartic' with new example sentence.
# Updated note with FrontText 'chastise' with new example sentence.
# Updated note with FrontText 'astute' with new example sentence.
# Updated note with FrontText 'commence' with new example sentence.
# Updated note with FrontText 'buoyant' with new example sentence.
# Updated note with FrontText 'benevolent' with new example sentence.
# Updated note with FrontText 'berate' with new example sentence.
# Updated note with FrontText 'condone' with new example sentence.
# Updated note with FrontText 'archetype' with new example sentence.
# Updated note with FrontText 'appropriate' with new example sentence.
# Updated note with FrontText 'conspire' with new example sentence.
# Updated note with FrontText 'adverse' with new example sentence.
# Updated note with FrontText 'adept' with new example sentence.
# Updated note with FrontText 'articulate' with new example sentence.
# Updated note with FrontText 'cease' with new example sentence.
# Updated note with FrontText 'conducive' with new example sentence.
# Updated note with FrontText 'antagonize' with new example sentence.
# Updated note with FrontText 'barren' with new example sentence.
# Updated note with FrontText 'agitated' with new example sentence.
# Updated note with FrontText 'abstract' with new example sentence.
# Updated note with FrontText 'conviction' with new example sentence.
# Updated note with FrontText 'bravado' with new example sentence.
# Updated note with FrontText 'abide' with new example sentence.
# Updated note with FrontText 'aberrant' with new example sentence.
# Updated note with FrontText 'aghast' with new example sentence.
# Updated note with FrontText 'boon' with new example sentence.
# Updated note with FrontText 'caricature' with new example sentence.
